# %%
import pandas as pd
import math as mth
import numpy as np
import matplotlib.pyplot as plt

from datetime import datetime


import statsmodels.api as sm
from numpy.random import default_rng
from scipy import signal
from sklearn.decomposition import PCA

# %%
def contaminante_filtro(strcont,contaminante,f_inicio,f_final,date_filepath,date_columna):
    df12 = pd.read_csv(strcont)
    

    
    df12= df12[['Date',contaminante]]
    f_inicio = pd.to_datetime(f_inicio)
    f_final = pd.to_datetime(f_final)
    df12['Date'] = pd.to_datetime(df12['Date'])
    df12=df12.loc[(df12['Date'] >= f_inicio)&((df12['Date'] <= f_final))]
    df12 = df12.reset_index()
    df12=df12.sort_values(by='Date',ignore_index=True)
    
    suma = 0    
    c = 0
    for i in range(df12.shape[0]):
        if df12.loc[i,contaminante] == '-' or pd.isnull(df12.loc[i,contaminante]) == True or df12.loc[i,contaminante] == '_' or df12.loc[i,contaminante] =='ND' :
            continue
        else:
            #print(i,df12.loc[i,contaminante])
            suma = float(df12.loc[i,contaminante])+suma
            c+=1
            
    media = suma /c
    print(media)
            
    for i in range(df12.shape[0]):
        if df12.loc[i,contaminante] == '-' or  pd.isnull(df12.loc[i,contaminante]) == True or df12.loc[i,contaminante] == '_' or  df12.loc[i,contaminante] =='ND':
            df12.loc[i,contaminante] = media
    df12[contaminante]= df12[contaminante].astype(float)
    
    date12 = pd.read_csv(date_filepath)
    date12[date_columna] = pd.to_datetime(date12[date_columna])
    date12=date12.sort_values(by=date_columna,ignore_index=True)
            
   
    lcont12 = []
    suma = df12.loc[0,contaminante]
    h = 1
    c = 0
    for j in range(df12.shape[0]):
        if j == df12.shape[0]-1:
            
            if df12.loc[j,'Date'] != df12.loc[j-1,'Date']:
                lcont12.append(df12.loc[j,contaminante])
            else:
                res=suma/h
                lcont12.append(res)
            continue
        elif df12.loc[j,'Date'] != date12.loc[c,date_columna]:
            
            while df12.loc[j,'Date'] != date12.loc[c,date_columna]:
                #print('bucle primero',df12.loc[j,'Date'], date12.loc[c,date_columna])
                c+=1
                lcont12.append(media)
            
                
        elif df12.loc[j,'Date'] == date12.loc[c,date_columna]:
            if df12.loc[j,'Date'] == df12.loc[j+1,'Date']:
                suma = df12.loc[j+1,contaminante]+suma
                h+=1
            elif df12.loc[j,'Date'] != df12.loc[j+1,'Date']:
                #print('diferencia',df12.loc[j+1,'Date'])
                res=suma/h
                lcont12.append(res)
                h=1
                suma =df12.loc[j+1,contaminante]
                c+=1
                while df12.loc[j+1,'Date'] != date12.loc[c,date_columna]:
                    #print('segundo  while',df12.loc[j+1,'Date'], date12.loc[c,date_columna])
                    c+=1
                    lcont12.append(media)
                    
            
            
    print('lista de contaminantes:',len(lcont12))
    
    if 31<len(lcont12)<365:
        for i in range(365-len(lcont12)):
            lcont12.append(media)
            
    l_media = []
    for i in range(5):
        l_media.append(media)
        
            
            

    return lcont12,l_media

# %%
def enfermedades_filtro(año,edad_i,edad_f,fecha_i,fecha_f,municipio,date_columna,date_filepath,enf_clave):
    enf12 = pd.read_csv(año)
    
    enf12['EDAD']=enf12['EDAD'].astype(float)
    enf12['MUNIC']=enf12['MUNIC'].astype(float)
    enf12['AFECPRIN']=enf12['AFECPRIN'].astype(str)   
    
    enf12=enf12.loc[enf12['MUNIC'] == municipio]
    enf12=enf12.loc[(enf12['EDAD'] >= edad_i) & (enf12['EDAD'] <= edad_f )]
    
    
    enf12['INGRE'] = pd.to_datetime(enf12['INGRE'], errors = 'coerce')
    enf12=enf12.sort_values(by='INGRE',ignore_index=True)
    
    fecha_i= pd.to_datetime(fecha_i)
    fecha_f = pd.to_datetime(fecha_f)
    enf12=enf12.loc[(enf12['INGRE'] >= fecha_i)&(enf12['INGRE'] <= fecha_f)]
    enf12=enf12.reset_index() 
    
    for a in range(enf12.shape[0]):
        if isinstance(enf12.loc[a,'AFECPRIN'],str) == False :
            enf12=enf12.drop(a, axis=0)
            
    if enf_clave == 'JI' or enf_clave == 'IJ':
        enf12=enf12.loc[(enf12["AFECPRIN"].str.contains('I')) | (enf12["AFECPRIN"].str.contains('J'))]
    elif enf_clave == 'J':
        enf12=enf12.loc[(enf12["AFECPRIN"].str.contains('J'))]
    elif enf_clave == 'I':
        enf12=enf12.loc[(enf12["AFECPRIN"].str.contains('I'))]
            
    
    enf12=enf12.reset_index() 
    
    enf12=enf12[['INGRE','EDAD','SEXO','MUNIC','AFECPRIN']]
           
            
 
    date12 = pd.read_csv(date_filepath)
    date12[date_columna] = pd.to_datetime(date12[date_columna])
    date12=date12.sort_values(by=date_columna,ignore_index=True)
    
    
    p=1
    h = 0
    lenf=[]
    print(date_columna)
    for g in range(enf12.shape[0]): 
        if g == enf12.shape[0]-1:
            if enf12.loc[g,'INGRE']!=enf12.loc[g-1,'INGRE']:
                lenf.append(1)
            continue  
        elif date12.loc[h,date_columna] != enf12.loc[g,'INGRE']:
            while enf12.loc[g+1,'INGRE'] != date12.loc[h,date_columna]:
                    h=h+1
                    lenf.append(0)
        
        elif date12.loc[h,date_columna] == enf12.loc[g,'INGRE']:
            
            if enf12.loc[g,'INGRE'] == enf12.loc[g+1,'INGRE']:
                p+=1            
            
            if enf12.loc[g,'INGRE'] != enf12.loc[g+1,'INGRE']:
                h=h+1
                lenf.append(p)
                p=1
                while enf12.loc[g+1,'INGRE'] != date12.loc[h,date_columna]:
                    h=h+1
                    lenf.append(0)
                                       
        else:
            h+=1
            lenf.append(0)

    
    print(len(lenf)) 
    dias = 0
    if date_columna == 'date12' or date_columna == 'date16':
        dias = 366
    else:
        dias = 365

 
    j=0
    for i in lenf:
        j = j+i
    media = j/len(lenf)
    print(media)
        
    if len(lenf)<dias:
        dif = dias-len(lenf)
        for i in range(dif):
            lenf.append(media)
    print('lista enfermedades:',len(lenf))
    lenf = np.array(lenf)
    return lenf

# %%
def proy_arima(lcont_28dias, lista_cont):
    lconti = lcont_28dias + lista_cont
    I=[]
    for i in range(len(lconti)):
        if i == 0:
            continue
        diff=lconti[i]-lconti[i-1]
        I.append(diff)
    #print(len(lcont12))
    
    wsize = 5
    j = 0
# metodo moving averages
    ma = []
    while j < len(I) - wsize + 1:
        window = I[j : j + wsize]
        waverage = sum(window) / wsize
        
        ma.append(waverage)
        j += 1
#ma=ma[1:364]

    ma.pop(0)
    #print(len(ma))    

    arima12=[]
    arima12.append(lista_cont[0])
    for x in range(len(ma)):
        arima12.append(arima12[x]+ma[x])
    print("Arima longitud:",len(arima12))
    return arima12

# %%
def lowess_corr_proy(tempdb,año,arima,enfermedad,contaminante,lista_humedad):
    #registro.append(año)
    
    if año == 2012 or año == 2016:
        dmes = [31,29,31,30,31,30,31,31,30,31,30,31]
    else:
        dmes = [31,28,31,30,31,30,31,31,30,31,30,31]
        
    ltemp = []
    
    for i in range(len(dmes)):
        for j in range(dmes[i]):
            ltemp.append(tempdb[i])
    nobs = []
    ja = 1
    for x in arima:
        nobs.append(ja)
        ja += 1
        
    vect = []
    for i in range(len(enfermedad)):
        vect.append(i)
        
    nobsxk=[list(y) for y in zip(nobs, arima)]
    nxk=np.array(nobsxk)
    
    lowess = sm.nonparametric.lowess
    res_low=lowess(enfermedad, vect)
    #print(res_low)
    
    low12=[]
    for i in range(len(res_low)):
        low12.append(res_low[i][1])
        
    correlation = signal.correlate(lista_humedad, low12, mode="full")
    lags = signal.correlation_lags(366, 366, mode="full")
    lag = lags[np.argmax(correlation)]
    np.argmax(correlation) - correlation.size/2
    
    
    #print("lags en temperatura y enfermedades",lag)
    
    ltemp = [float(ele) for ele in ltemp]
    corr_temp = signal.correlate(ltemp, low12, mode="full")
    lags_temp = signal.correlation_lags(366, 366, mode="full")
    lag_temp = lags[np.argmax(correlation)]
    np.argmax(correlation) - correlation.size/2
    
   

    
    pca=[list(y) for y in zip(low12, arima,lista_humedad)]
    pca = np.array(pca) 
    pca_model = PCA(n_components=3)
    pca_model.fit(pca)
    x_pca = pca_model.transform(pca)
    #print(nxk)
    gamma_model = sm.GLM(enfermedad, nxk, family=sm.families.Poisson())
    gamma_results = gamma_model.fit()
    print(gamma_results.summary())
    
    gamma_param = gamma_results.params
    
    print('parametro',gamma_param[0])
    print('parametro',gamma_param[1])
    registro.append(año)
    registro.append(gamma_param[0])
    registro.append(gamma_param[1])
    for i in range(len(gamma_param)):
        if gamma_param[i]>= 709:
            registro.append('limite de registro')
        else:
            print('parametro bajo exponente', mth.exp(gamma_param[i]))
            registro.append(mth.exp(gamma_param[i]))
    
   

    
    print(registro)
    bucle.append(registro[:])
    registro.clear()

# %%
def union_lista(path_mira,path_tlaque, contaminante,fecha_inicio,fecha_final,fecha_columna):
    
    if  contaminante != 'RH':     
        registro.append('san_pedro')
        registro.append(contaminante)
        print('Este es el contaminante:',registro)
        
    lcont_mira,lma_mira = contaminante_filtro(path_mira,contaminante,fecha_inicio,fecha_final,db_date,fecha_columna)
    lcont_tlaque,lma_tlaque = contaminante_filtro(path_tlaque,contaminante,fecha_inicio,fecha_final,db_date,fecha_columna)
    lcontaminante = []
    lma = []
    for i in range(len(lcont_mira)):
        lcontaminante.append(lcont_mira[i] + lcont_tlaque[i]) 
    for i in range(5):
        lma.append(lma_mira[i] + lma_tlaque[i])
    print(len(lma))
    return lcontaminante, lma

# %%
def db_resultados():
    for i in bucle:
        df.loc[len(df)] = i

# %%
path_mira = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/sanpedro/miradb.csv'
path_tlaque =  'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/sanpedro/tlaquedb.csv'
path_enf = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos enfermedades/enfdb.csv'
db_date = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos enfermedades/dates.csv'
db_2011 = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/datos_2011.csv'

# %%
df = pd.DataFrame(columns= ['Municipio','Contaminante','Anio','B0','B1','e^B0','e^B1'])

# %%
df
# Out:
#     Municipio Contaminante  Anio        B0          B1      e^B0          e^B1
# 0   san_pedro           O3  2012 -0.003601  -28.426830  0.996406  4.512163e-13
# 1   san_pedro          NO2  2012 -0.003453  -16.378244  0.996553  7.709373e-08
# 2   san_pedro          SO2  2012 -0.004317  -97.243245  0.995692  5.858618e-43
# 3   san_pedro           CO  2012 -0.003332   -0.234166  0.996674  7.912306e-01
# 4   san_pedro         PM10  2012 -0.003443   -0.004959  0.996563  9.950530e-01
# 5   san_pedro           O3  2013 -0.002163  -23.036620  0.997840  9.892890e-11
# 6   san_pedro          NO2  2013 -0.001953  -11.507343  0.998049  1.005598e-05
# 7   san_pedro          SO2  2013 -0.002520  -90.471825  0.997483  5.111940e-40
# 8   san_pedro           CO  2013 -0.001517   -0.465098  0.998484  6.280734e-01
# 9   san_pedro         PM10  2013 -0.002341   -0.009734  0.997661  9.903130e-01
# 10  san_pedro           O3  2015 -0.001969  -21.154425  0.998033  6.497556e-10
# 11  san_pedro          NO2  2015 -0.001239  -20.948670  0.998762  7.981936e-10
# 12  san_pedro          SO2  2015 -0.002255 -134.677584  0.997748  3.237936e-59
# 13  san_pedro           CO  2015 -0.001259   -0.339781  0.998742  7.119261e-01
# 14  san_pedro         PM10  2015 -0.001502   -0.004004  0.998499  9.960043e-01
# 15  san_pedro           O3  2016 -0.002632 -140.980316  0.997372  5.929618e-62
# 16  san_pedro          NO2  2016 -0.001935  -72.017400  0.998067  5.287380e-32
# 17  san_pedro           CO  2016 -0.000115   -0.937532  0.999885  3.915933e-01
# 18  san_pedro         PM10  2016  0.000549   -0.028445  1.000550  9.719555e-01

# %%
bucle = []
registro = []
metodol('JI',75,120)
# Out:
# Este es el contaminante: ['san_pedro', 'O3']
# 0.016305238589212463
# lista de contaminantes: 366
# 0.021029916753382012
# lista de contaminantes: 366
# 5
# 51.48900249673047
# lista de contaminantes: 366
# 48.9616818020994
# lista de contaminantes: 366
# 5
# date12
# 365
# 0.16986301369863013
# lista enfermedades: 366
# Arima longitud: 366
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  366
# Model:                            GLM   Df Residuals:                      364
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -174.07
# Date:                Mon, 14 Nov 2022   Deviance:                       227.52
# Time:                        01:29:53   Pearson chi2:                     350.
# No. Iterations:                     6   Pseudo R-squ. (CS):           0.001706
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0036      0.001     -3.455      0.001      -0.006      -0.002
# x2           -28.4268      4.819     -5.899      0.000     -37.872     -18.982
# ==============================================================================
# parametro -0.0036006483552741943
# parametro -28.426829669184404
# parametro bajo exponente 0.9964058262058113
# parametro bajo exponente 4.512162550175417e-13
# ['san_pedro', 'O3', 2012, -0.0036006483552741943, -28.426829669184404, 0.9964058262058113, 4.512162550175417e-13]
# Este es el contaminante: ['san_pedro', 'NO2']
# 0.041434486927610634
# lista de contaminantes: 366
# 0.017447694174757597
# lista de contaminantes: 366
# 5
# Arima longitud: 366
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  366
# Model:                            GLM   Df Residuals:                      364
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -176.78
# Date:                Mon, 14 Nov 2022   Deviance:                       232.93
# Time:                        01:30:00   Pearson chi2:                     423.
# No. Iterations:                     6   Pseudo R-squ. (CS):           -0.01317
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0035      0.001     -2.826      0.005      -0.006      -0.001
# x2           -16.3782      3.092     -5.297      0.000     -22.438     -10.318
# ==============================================================================
# parametro -0.0034526581533707106
# parametro -16.378243901688226
# parametro bajo exponente 0.9965532954169393
# parametro bajo exponente 7.709372853159504e-08
# ['san_pedro', 'NO2', 2012, -0.0034526581533707106, -16.378243901688226, 0.9965532954169393, 7.709372853159504e-08]
# Este es el contaminante: ['san_pedro', 'SO2']
# 0.0032643089809213364
# lista de contaminantes: 366
# 0.003569344318571929
# lista de contaminantes: 366
# 5
# Arima longitud: 366
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  366
# Model:                            GLM   Df Residuals:                      364
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -175.66
# Date:                Mon, 14 Nov 2022   Deviance:                       230.69
# Time:                        01:30:09   Pearson chi2:                     367.
# No. Iterations:                     6   Pseudo R-squ. (CS):          -0.007002
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0043      0.001     -3.976      0.000      -0.006      -0.002
# x2           -97.2432     18.325     -5.307      0.000    -133.160     -61.326
# ==============================================================================
# parametro -0.004316982632145338
# parametro -97.24324530120343
# parametro bajo exponente 0.9956923221430447
# parametro bajo exponente 5.858617753603006e-43
# ['san_pedro', 'SO2', 2012, -0.004316982632145338, -97.24324530120343, 0.9956923221430447, 5.858617753603006e-43]
# Este es el contaminante: ['san_pedro', 'CO']
# 0.8885675465838543
# lista de contaminantes: 366
# 1.751735914727008
# lista de contaminantes: 366
# 5
# Arima longitud: 366
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  366
# Model:                            GLM   Df Residuals:                      364
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -174.71
# Date:                Mon, 14 Nov 2022   Deviance:                       228.78
# Time:                        01:30:16   Pearson chi2:                     363.
# No. Iterations:                     6   Pseudo R-squ. (CS):          -0.001761
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0033      0.001     -2.864      0.004      -0.006      -0.001
# x2            -0.2342      0.042     -5.610      0.000      -0.316      -0.152
# ==============================================================================
# parametro -0.003331852443771757
# parametro -0.23416581091215863
# parametro bajo exponente 0.9966736920170972
# parametro bajo exponente 0.791230610348999
# ['san_pedro', 'CO', 2012, -0.003331852443771757, -0.23416581091215863, 0.9966736920170972, 0.791230610348999]
# Este es el contaminante: ['san_pedro', 'PM10']
# 60.677615012106415
# lista de contaminantes: 366
# 54.65530612244887
# lista de contaminantes: 366
# 5
# Arima longitud: 366
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  366
# Model:                            GLM   Df Residuals:                      364
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -176.57
# Date:                Mon, 14 Nov 2022   Deviance:                       232.50
# Time:                        01:30:22   Pearson chi2:                     396.
# No. Iterations:                     6   Pseudo R-squ. (CS):           -0.01199
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0034      0.001     -2.869      0.004      -0.006      -0.001
# x2            -0.0050      0.001     -5.371      0.000      -0.007      -0.003
# ==============================================================================
# parametro -0.003442624306192817
# parametro -0.0049592500001139975
# parametro bajo exponente 0.9965632947305758
# parametro bajo exponente 0.9950530267772474
# ['san_pedro', 'PM10', 2012, -0.003442624306192817, -0.0049592500001139975, 0.9965632947305758, 0.9950530267772474]
# Este es el contaminante: ['san_pedro', 'O3']
# 0.01981384425216371
# lista de contaminantes: 365
# 0.019370633510953725
# lista de contaminantes: 365
# 5
# 53.36961848092399
# lista de contaminantes: 365
# 50.11875071764803
# lista de contaminantes: 365
# 5
# date13
# 354
# 0.3644067796610169
# lista enfermedades: 365
# Arima longitud: 365
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  365
# Model:                            GLM   Df Residuals:                      363
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -277.26
# Date:                Mon, 14 Nov 2022   Deviance:                       307.02
# Time:                        01:30:40   Pearson chi2:                     327.
# No. Iterations:                     5   Pseudo R-squ. (CS):           0.007237
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0022      0.001     -3.744      0.000      -0.003      -0.001
# x2           -23.0366      4.249     -5.421      0.000     -31.365     -14.708
# ==============================================================================
# parametro -0.0021625792540987446
# parametro -23.03661966828864
# parametro bajo exponente 0.9978397574356872
# parametro bajo exponente 9.892890369396603e-11
# ['san_pedro', 'O3', 2013, -0.0021625792540987446, -23.03661966828864, 0.9978397574356872, 9.892890369396603e-11]
# Este es el contaminante: ['san_pedro', 'NO2']
# 0.03098251287579301
# lista de contaminantes: 365
# 0.021799952707495813
# lista de contaminantes: 365
# 5
# Arima longitud: 365
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  365
# Model:                            GLM   Df Residuals:                      363
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -281.02
# Date:                Mon, 14 Nov 2022   Deviance:                       314.53
# Time:                        01:30:45   Pearson chi2:                     329.
# No. Iterations:                     5   Pseudo R-squ. (CS):           -0.01339
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0020      0.001     -2.803      0.005      -0.003      -0.001
# x2           -11.5073      2.457     -4.683      0.000     -16.323      -6.691
# ==============================================================================
# parametro -0.0019529734161769586
# parametro -11.507343495346358
# parametro bajo exponente 0.9980489323955367
# parametro bajo exponente 1.0055975778443345e-05
# ['san_pedro', 'NO2', 2013, -0.0019529734161769586, -11.507343495346358, 0.9980489323955367, 1.0055975778443345e-05]
# Este es el contaminante: ['san_pedro', 'SO2']
# 0.005382249961942529
# lista de contaminantes: 365
# 0.001748236953455546
# lista de contaminantes: 365
# 5
# Arima longitud: 365
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  365
# Model:                            GLM   Df Residuals:                      363
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -290.81
# Date:                Mon, 14 Nov 2022   Deviance:                       334.11
# Time:                        01:30:51   Pearson chi2:                     335.
# No. Iterations:                     5   Pseudo R-squ. (CS):           -0.06925
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0025      0.001     -2.827      0.005      -0.004      -0.001
# x2           -90.4718     33.762     -2.680      0.007    -156.645     -24.299
# ==============================================================================
# parametro -0.0025196792443256955
# parametro -90.47182465293659
# parametro bajo exponente 0.9974834924829504
# parametro bajo exponente 5.111940444268939e-40
# ['san_pedro', 'SO2', 2013, -0.0025196792443256955, -90.47182465293659, 0.9974834924829504, 5.111940444268939e-40]
# Este es el contaminante: ['san_pedro', 'CO']
# 0.7607520651262993
# lista de contaminantes: 365
# 0.7346753298153073
# lista de contaminantes: 365
# 5
# Arima longitud: 365
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  365
# Model:                            GLM   Df Residuals:                      363
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -282.63
# Date:                Mon, 14 Nov 2022   Deviance:                       317.76
# Time:                        01:30:56   Pearson chi2:                     330.
# No. Iterations:                     5   Pseudo R-squ. (CS):           -0.02239
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0015      0.001     -1.896      0.058      -0.003    5.11e-05
# x2            -0.4651      0.104     -4.472      0.000      -0.669      -0.261
# ==============================================================================
# parametro -0.0015174033170330034
# parametro -0.46509824165211333
# parametro bajo exponente 0.9984837473572943
# parametro bajo exponente 0.6280733991902558
# ['san_pedro', 'CO', 2013, -0.0015174033170330034, -0.46509824165211333, 0.9984837473572943, 0.6280733991902558]
# Este es el contaminante: ['san_pedro', 'PM10']
# 66.260712055109
# lista de contaminantes: 365
# 44.547012706137004
# lista de contaminantes: 365
# 5
# Arima longitud: 365
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  365
# Model:                            GLM   Df Residuals:                      363
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -281.68
# Date:                Mon, 14 Nov 2022   Deviance:                       315.85
# Time:                        01:31:05   Pearson chi2:                     333.
# No. Iterations:                     5   Pseudo R-squ. (CS):           -0.01708
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0023      0.001     -3.685      0.000      -0.004      -0.001
# x2            -0.0097      0.002     -4.625      0.000      -0.014      -0.006
# ==============================================================================
# parametro -0.0023412515785134302
# parametro -0.009734272245471187
# parametro bajo exponente 0.9976614870133025
# parametro bajo exponente 0.9903129524257811
# ['san_pedro', 'PM10', 2013, -0.0023412515785134302, -0.009734272245471187, 0.9976614870133025, 0.9903129524257811]
# Este es el contaminante: ['san_pedro', 'O3']
# 0.017569679577464678
# lista de contaminantes: 365
# 0.019025937683715567
# lista de contaminantes: 365
# 5
# 57.66442385639857
# lista de contaminantes: 365
# 53.80365754222482
# lista de contaminantes: 365
# 5
# date15
# 350
# 0.32857142857142857
# lista enfermedades: 365
# Arima longitud: 365
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  365
# Model:                            GLM   Df Residuals:                      363
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -263.05
# Date:                Mon, 14 Nov 2022   Deviance:                       301.07
# Time:                        01:31:20   Pearson chi2:                     345.
# No. Iterations:                     5   Pseudo R-squ. (CS):          0.0008912
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0020      0.001     -2.711      0.007      -0.003      -0.001
# x2           -21.1544      4.046     -5.229      0.000     -29.084     -13.225
# ==============================================================================
# parametro -0.0019686377733464256
# parametro -21.154424890765256
# parametro bajo exponente 0.9980332987230331
# parametro bajo exponente 6.497555564529482e-10
# ['san_pedro', 'O3', 2015, -0.0019686377733464256, -21.154424890765256, 0.9980332987230331, 6.497555564529482e-10]
# Este es el contaminante: ['san_pedro', 'NO2']
# 0.020071501466275603
# lista de contaminantes: 365
# 0.020269854306192
# lista de contaminantes: 365
# 5
# Arima longitud: 365
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  365
# Model:                            GLM   Df Residuals:                      363
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -261.65
# Date:                Mon, 14 Nov 2022   Deviance:                       298.26
# Time:                        01:31:25   Pearson chi2:                     333.
# No. Iterations:                     5   Pseudo R-squ. (CS):           0.008553
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0012      0.001     -1.408      0.159      -0.003       0.000
# x2           -20.9487      4.079     -5.136      0.000     -28.943     -12.954
# ==============================================================================
# parametro -0.0012392097105562673
# parametro -20.948669933700604
# parametro bajo exponente 0.9987615577927319
# parametro bajo exponente 7.981936061349536e-10
# ['san_pedro', 'NO2', 2015, -0.0012392097105562673, -20.948669933700604, 0.9987615577927319, 7.981936061349536e-10]
# Este es el contaminante: ['san_pedro', 'SO2']
# 0.003232444810091793
# lista de contaminantes: 365
# 0.0029781789212793646
# lista de contaminantes: 365
# 5
# Arima longitud: 365
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  365
# Model:                            GLM   Df Residuals:                      363
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -263.89
# Date:                Mon, 14 Nov 2022   Deviance:                       302.75
# Time:                        01:31:30   Pearson chi2:                     342.
# No. Iterations:                     5   Pseudo R-squ. (CS):          -0.003714
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0023      0.001     -2.950      0.003      -0.004      -0.001
# x2          -134.6776     28.164     -4.782      0.000    -189.877     -79.478
# ==============================================================================
# parametro -0.0022546560645751584
# parametro -134.67758445991106
# parametro bajo exponente 0.9977478837632383
# parametro bajo exponente 3.237935795895876e-59
# ['san_pedro', 'SO2', 2015, -0.0022546560645751584, -134.67758445991106, 0.9977478837632383, 3.237935795895876e-59]
# Este es el contaminante: ['san_pedro', 'CO']
# 0.8918741839727777
# lista de contaminantes: 365
# 0.9067615942029
# lista de contaminantes: 365
# 5
# Arima longitud: 365
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  365
# Model:                            GLM   Df Residuals:                      363
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -261.13
# Date:                Mon, 14 Nov 2022   Deviance:                       297.22
# Time:                        01:31:34   Pearson chi2:                     333.
# No. Iterations:                     5   Pseudo R-squ. (CS):            0.01138
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0013      0.001     -1.442      0.149      -0.003       0.000
# x2            -0.3398      0.066     -5.176      0.000      -0.468      -0.211
# ==============================================================================
# parametro -0.0012585785538871905
# parametro -0.3397811321752849
# parametro bajo exponente 0.9987422131239365
# parametro bajo exponente 0.7119261234341047
# ['san_pedro', 'CO', 2015, -0.0012585785538871905, -0.3397811321752849, 0.9987422131239365, 0.7119261234341047]
# Este es el contaminante: ['san_pedro', 'PM10']
# 59.18275915580395
# lista de contaminantes: 365
# 47.41270667330696
# lista de contaminantes: 365
# 5
# Arima longitud: 365
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  365
# Model:                            GLM   Df Residuals:                      363
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -260.16
# Date:                Mon, 14 Nov 2022   Deviance:                       295.28
# Time:                        01:31:40   Pearson chi2:                     330.
# No. Iterations:                     5   Pseudo R-squ. (CS):            0.01662
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0015      0.001     -1.849      0.064      -0.003    9.03e-05
# x2            -0.0040      0.001     -5.318      0.000      -0.005      -0.003
# ==============================================================================
# parametro -0.001501659725614346
# parametro -0.004003691450000825
# parametro bajo exponente 0.998499467201194
# parametro bajo exponente 0.9960043126370846
# ['san_pedro', 'PM10', 2015, -0.001501659725614346, -0.004003691450000825, 0.998499467201194, 0.9960043126370846]
# Este es el contaminante: ['san_pedro', 'O3']
# 0.018587686624595937
# lista de contaminantes: 366
# 0.018590689604325354
# lista de contaminantes: 366
# 5
# 51.9890902629707
# lista de contaminantes: 366
# 46.87273927014041
# lista de contaminantes: 366
# 5
# date16
# 205
# 0.014634146341463415
# lista enfermedades: 366
# Arima longitud: 366
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  366
# Model:                            GLM   Df Residuals:                      364
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -28.069
# Date:                Mon, 14 Nov 2022   Deviance:                       28.183
# Time:                        01:32:00   Pearson chi2:                     209.
# No. Iterations:                     7   Pseudo R-squ. (CS):          -0.007780
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0026      0.003     -0.829      0.407      -0.009       0.004
# x2          -140.9803     26.688     -5.283      0.000    -193.288     -88.673
# ==============================================================================
# parametro -0.002631647000519521
# parametro -140.98031595709128
# parametro bajo exponente 0.9973718127468381
# parametro bajo exponente 5.929618093790792e-62
# ['san_pedro', 'O3', 2016, -0.002631647000519521, -140.98031595709128, 0.9973718127468381, 5.929618093790792e-62]
# Este es el contaminante: ['san_pedro', 'NO2']
# 0.023321787207681532
# lista de contaminantes: 366
# 0.023540298952942643
# lista de contaminantes: 366
# 5
# Arima longitud: 366
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  366
# Model:                            GLM   Df Residuals:                      364
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -28.236
# Date:                Mon, 14 Nov 2022   Deviance:                       28.517
# Time:                        01:32:07   Pearson chi2:                     301.
# No. Iterations:                     7   Pseudo R-squ. (CS):          -0.008701
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0019      0.004     -0.474      0.636      -0.010       0.006
# x2           -72.0174     15.708     -4.585      0.000    -102.804     -41.231
# ==============================================================================
# parametro -0.0019352945657336008
# parametro -72.01740005698066
# parametro bajo exponente 0.9980665769093147
# parametro bajo exponente 5.287380368791598e-32
# ['san_pedro', 'NO2', 2016, -0.0019352945657336008, -72.01740005698066, 0.9980665769093147, 5.287380368791598e-32]
# Este es el contaminante: ['san_pedro', 'CO']
# 1.0485931268561715
# lista de contaminantes: 366
# 1.0329433996383348
# lista de contaminantes: 366
# 5
# Arima longitud: 366
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  366
# Model:                            GLM   Df Residuals:                      364
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -27.168
# Date:                Mon, 14 Nov 2022   Deviance:                       26.382
# Time:                        01:32:13   Pearson chi2:                     241.
# No. Iterations:                     7   Pseudo R-squ. (CS):          -0.002832
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0001      0.004     -0.026      0.979      -0.009       0.009
# x2            -0.9375      0.207     -4.523      0.000      -1.344      -0.531
# ==============================================================================
# parametro -0.00011508904698690302
# parametro -0.9375315042167467
# parametro bajo exponente 0.9998849175755034
# parametro bajo exponente 0.39159328964259227
# ['san_pedro', 'CO', 2016, -0.00011508904698690302, -0.9375315042167467, 0.9998849175755034, 0.39159328964259227]
# Este es el contaminante: ['san_pedro', 'PM10']
# 66.73909047619053
# lista de contaminantes: 366
# 37.27184947069454
# lista de contaminantes: 366
# 5
# Arima longitud: 366
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  366
# Model:                            GLM   Df Residuals:                      364
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -26.823
# Date:                Mon, 14 Nov 2022   Deviance:                       25.692
# Time:                        01:32:23   Pearson chi2:                     245.
# No. Iterations:                     7   Pseudo R-squ. (CS):         -0.0009439
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0005      0.004      0.129      0.898      -0.008       0.009
# x2            -0.0284      0.006     -4.700      0.000      -0.040      -0.017
# ==============================================================================
# parametro 0.0005494526626356074
# parametro -0.028445248267011065
# parametro bajo exponente 1.0005496036394002
# parametro bajo exponente 0.9719555089378247
# ['san_pedro', 'PM10', 2016, 0.0005494526626356074, -0.028445248267011065, 1.0005496036394002, 0.9719555089378247]

# %%
df.to_csv('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/sanpedro/sanpedro_75_120.csv')

# %%
def metodol(tipo_enf,edad_inicial,edad_final):

    
    temp12 = [16.7, 17.7, 19.9, 20.9, 24, 23.3, 22.1, 22.2, 21.1, 20.6, 18.8, 17.2, 20.4]

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'O3','2012/01/01','2012/12/31','date12')
    lista_hum,lhum_media = union_lista(path_mira,path_tlaque, 'RH','2012/01/01','2012/12/31','date12')
    lista_enf = enfermedades_filtro(path_enf,edad_inicial,edad_final,'2012/01/01','2012/12/31',98,'date12',db_date,tipo_enf)
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp12,2012,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'NO2','2012/01/01','2012/12/31','date12')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp12,2012,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'SO2','2012/01/01','2012/12/31','date12')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp12,2012,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'CO','2012/01/01','2012/12/31','date12')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp12,2012,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'PM10','2012/01/01','2012/12/31','date12')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp12,2012,larima,lista_enf,lista_cont,lista_hum)
    

    temp13 = [16.9, 18.8, 19.2, 22.1, 22.9, 24.6, 22.4, 22.7, 22.1, 21.8, 19.1, 17.0,20.8 ]

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'O3','2013/01/01','2013/12/31','date13')
    lista_hum,lhum_media = union_lista(path_mira,path_tlaque, 'RH','2013/01/01','2013/12/31','date13')
    lista_enf = enfermedades_filtro(path_enf,edad_inicial,edad_final,'2013/01/01','2013/12/31',98,'date13',db_date,tipo_enf)
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp13,2013,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'NO2','2013/01/01','2013/12/31','date13')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp13,2013,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'SO2','2013/01/01','2013/12/31','date13')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp13,2013,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'CO','2013/01/01','2013/12/31','date13')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp13,2013,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'PM10','2013/01/01','2013/12/31','date13')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp13,2013,larima,lista_enf,lista_cont,lista_hum)


    temp15 = [18.0, 18.4, 19.3, 22.6, 23.8, 23.8, 22.9, 23.2, 22.8, 21.9, 20.8, 18.6]

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'O3','2015/01/01','2015/12/31','date15')
    lista_hum,lhum_media = union_lista(path_mira,path_tlaque, 'RH','2015/01/01','2015/12/31','date15')
    lista_enf = enfermedades_filtro(path_enf,edad_inicial,edad_final,'2015/01/01','2015/12/31',98,'date15',db_date,tipo_enf)
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp15,2015,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'NO2','2015/01/01','2015/12/31','date15')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp15,2015,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'SO2','2015/01/01','2015/12/31','date15')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp15,2015,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'CO','2015/01/01','2015/12/31','date15')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp15,2015,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'PM10','2015/01/01','2015/12/31','date15')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp15,2015,larima,lista_enf,lista_cont,lista_hum)
    
    temp16 = [17.2, 18.8,19.9, 22.4, 25.3, 24.3, 23.2, 23.1, 22.9, 22.5, 19.7, 18.6]

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'O3','2016/01/01','2016/12/31','date16')
    lista_hum,lhum_media = union_lista(path_mira,path_tlaque, 'RH','2016/01/01','2016/12/31','date16')
    lista_enf = enfermedades_filtro(path_enf,edad_inicial,edad_final,'2016/01/01','2016/12/31',98,'date16',db_date,tipo_enf)
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp16,2016,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'NO2','2016/01/01','2016/12/31','date16')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp16,2016,larima,lista_enf,lista_cont,lista_hum)

    #lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'SO2','2016/01/01','2016/12/31','date16')
    #larima = proy_arima(lcont_media, lista_cont)
    #lowess_corr_proy(temp16,2016,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'CO','2016/01/01','2016/12/31','date16')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp16,2016,larima,lista_enf,lista_cont,lista_hum)

    lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'PM10','2016/01/01','2016/12/31','date16')
    larima = proy_arima(lcont_media, lista_cont)
    lowess_corr_proy(temp16,2016,larima,lista_enf,lista_cont,lista_hum)
    db_resultados()

# %%
lista_enf
# Out:
#          INGRE  EDAD  SEXO  MUNIC AFECPRIN
# 0   2012-01-01   1.0   2.0   98.0     J219
# 1   2012-01-02  77.0   2.0   98.0     J188
# 2   2012-01-02  75.0   2.0   98.0     J90X
# 3   2012-01-03  69.0   1.0   98.0     J188
# 4   2012-01-06  21.0   1.0   98.0     J330
# ..         ...   ...   ...    ...      ...
# 254 2012-12-29  45.0   1.0   98.0     J22X
# 255 2012-12-29   3.0   2.0   98.0     J129
# 256 2012-12-29   1.0   1.0   98.0     J129
# 257 2012-12-30   9.0   1.0   98.0     J129
# 258 2012-12-30   4.0   1.0   98.0     J042
#
# [259 rows x 5 columns]

# %%
path_mira = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/sanpedro/miradb.csv'
path_tlaque =  'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/sanpedro/tlaquedb.csv'
path_enf = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos enfermedades/enfdb.csv'
db_date = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos enfermedades/dates.csv'
db_2011 = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/datos_2011.csv'
    
temp12 = [16.7, 17.7, 19.9, 20.9, 24, 23.3, 22.1, 22.2, 21.1, 20.6, 18.8, 17.2, 20.4]

lista_cont,lcont_media  = union_lista(path_mira,path_tlaque, 'O3','2012/01/01','2012/12/31','date12')
lista_hum,lhum_media = union_lista(path_mira,path_tlaque, 'RH','2012/01/01','2012/12/31','date12')
lista_enf = enfermedades_filtro(path_enf,0,100,'2012/01/01','2012/12/31',98,'date12',db_date,'J')
larima = proy_arima(lcont_media, lista_cont)
lowess_corr_proy(temp12,2012,larima,lista_enf,lista_cont,lista_hum)
# Out:
# Este es el contaminante: ['san_pedro', 'O3', 'san_pedro', 'O3', 'san_pedro', 'O3', 'san_pedro', 'O3']
# 0.016305238589212463
# lista de contaminantes: 366
# 0.021029916753382012
# lista de contaminantes: 366
# 5
# 51.48900249673047
# lista de contaminantes: 366
# 48.9616818020994
# lista de contaminantes: 366
# 5
# date12
# 364
# 0.7060439560439561
# lista enfermedades: 366
# Arima longitud: 366
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-d4aee77889fe> in <module>
#      11 lista_enf = enfermedades_filtro(path_enf,0,100,'2012/01/01','2012/12/31',98,'date12',db_date,'J')
#      12 larima = proy_arima(lcont_media, lista_cont)
# ---> 13 lowess_corr_proy(temp12,2012,larima,lista_enf,lista_cont,lista_hum)
#
# <ipython-input-6-916f76a1c2e6> in lowess_corr_proy(tempdb, año, arima, enfermedad, contaminante, lista_humedad)
#      26
#      27     lowess = sm.nonparametric.lowess
# ---> 28     res_low=lowess(enfermedad, vect)
#      29     #print(res_low)
#      30
#
# ~\AppData\Roaming\Python\Python39\site-packages\statsmodels\nonparametric\smoothers_lowess.py in lowess(endog, exog, frac, it, delta, xvals, is_sorted, missing, return_sorted)
#     136     '''
#     137
# --> 138     endog = np.asarray(endog, float)
#     139     exog = np.asarray(exog, float)
#     140
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1897
#    1898     def __array__(self, dtype=None) -> np.ndarray:
# -> 1899         return np.asarray(self._values, dtype=dtype)
#    1900
#    1901     def __array_wrap__(
#
# ~\AppData\Roaming\Python\Python39\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order, like)
#     100         return _asarray_with_like(a, dtype=dtype, order=order, like=like)
#     101
# --> 102     return array(a, dtype, copy=False, order=order)
#     103
#     104
#
# TypeError: float() argument must be a string or a number, not 'Timestamp'

# %%
#1 masculino, 2 femenino
def enf_filtro(año,edad_i,edad_f,fecha_i,fecha_f,municipio,date_filepath,enf_clave,sexo):
    enf12 = pd.read_csv(año)
    
    enf12['EDAD']=enf12['EDAD'].astype(float)
    enf12['MUNIC']=enf12['MUNIC'].astype(float)
    enf12['AFECPRIN']=enf12['AFECPRIN'].astype(str) 
    enf12['SEXO']=enf12['SEXO'].astype(str) 
    
    enf12=enf12.loc[enf12['MUNIC'] == municipio]
#    if sexo == '1' or sexo == '2' or sexo == '3' or sexo == '9':
#        enf12=enf12.loc[enf12['SEXO'] == sexo]

    
    enf12=enf12.loc[(enf12['EDAD'] >= edad_i) & (enf12['EDAD'] <= edad_f )]
    
    
    enf12['INGRE'] = pd.to_datetime(enf12['INGRE'], errors = 'coerce')
    enf12=enf12.sort_values(by='INGRE',ignore_index=True)
    
    fecha_i= pd.to_datetime(fecha_i)
    fecha_f = pd.to_datetime(fecha_f)
    enf12=enf12.loc[(enf12['INGRE'] >= fecha_i)&(enf12['INGRE'] <= fecha_f)]
    enf12=enf12.reset_index() 
    
    for a in range(enf12.shape[0]):
        if isinstance(enf12.loc[a,'AFECPRIN'],str) == False :
            enf12=enf12.drop(a, axis=0)
            
    if enf_clave == 'JI' or enf_clave == 'IJ':
        enf12=enf12.loc[(enf12["AFECPRIN"].str.contains('I')) | (enf12["AFECPRIN"].str.contains('J'))]
    elif enf_clave == 'J':
        enf12=enf12.loc[(enf12["AFECPRIN"].str.contains('J'))]
    elif enf_clave == 'I':
        enf12=enf12.loc[(enf12["AFECPRIN"].str.contains('I'))]
            
    
    enf12=enf12.reset_index() 
    
    enf12=enf12[['INGRE','EDAD','SEXO','MUNIC','AFECPRIN']]
    #display(enf12)
    
    
    suma_enf = enf12.shape[0]
    media_diag = 0
    t = 1
    valor = 0
    lmedia_enf = []
    for i in range(enf12.shape[0]):
        #print(enf12.loc[i,'INGRE'])
        if i == enf12.shape[0]-1 :
            valor = enf12.loc[i,'INGRE'].day
            t+=1
            media_diag = t/valor
            lmedia_enf.append(media_diag)            
            continue
        elif enf12.loc[i,'INGRE'].month == enf12.loc[i+1,'INGRE'].month:
            t+= 1
            
        elif enf12.loc[i,'INGRE'].month != enf12.loc[i+1,'INGRE'].month:
            valor = enf12.loc[i,'INGRE'].day
            media_diag = t/valor
            lmedia_enf.append(media_diag)
            t=1
            
        return enf12, lmedia_enf

# %%
def ciclo_enf(lenf,año):
    axc = ['C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/sanpedro/sanpedro_enf_media_','2016','.jpg']
    axc[1] = año
    axc = ''.join(axc)
    x = ['enero', 'feb','marzo','abril','mayo','junio','julio','agosto','sep','oct','nov','dic']


    plt.plot(x,lenf,label = año)
    plt.title("sanpedro_enfermedades_media_mensual")
    plt.legend()
    plt.savefig(axc)

# %%
sum_enf_4  = enf_filtro(path_enf,0,4,'2012/01/01','2016/12/31',98,db_date,'IJ','2.0')
sum_enf_59 = enf_filtro(path_enf,5,59,'2012/01/01','2016/12/31',98,db_date,'IJ','2.0')
sum_enf_74 = enf_filtro(path_enf,60,74,'2012/01/01','2016/12/31',98,db_date,'IJ','2.0')
sum_enf_120 = enf_filtro(path_enf,75,120,'2012/01/01','2016/12/31',98,db_date,'IJ','2.0')

# %%
y = [sum_enf_4, sum_enf_59, sum_enf_74, sum_enf_120]
x = ['0_4', '5_59','60_74','75_']


plt.bar(x,y, hatch = '/')
plt.title("sanpedro_femenino_edades")
plt.savefig('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/sanpedro/sanpedro_fem_edades.jpg')

# %%
sum_enf_4  = enf_filtro(path_enf,0,4,'2012/01/01','2016/12/31',98,db_date,'IJ','1.0')
sum_enf_59 = enf_filtro(path_enf,5,59,'2012/01/01','2016/12/31',98,db_date,'IJ','1.0')
sum_enf_74 = enf_filtro(path_enf,60,74,'2012/01/01','2016/12/31',98,db_date,'IJ','1.0')
sum_enf_120 = enf_filtro(path_enf,75,120,'2012/01/01','2016/12/31',98,db_date,'IJ','1.0')

# %%
y = [sum_enf_4, sum_enf_59, sum_enf_74, sum_enf_120]
x = ['0_4', '5_59','60_74','75_']


plt.bar(x,y, hatch = '/')
plt.title("masc_femenino_edades")
plt.savefig('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/sanpedro/sanpedro_masc_edades.jpg')

# %%
sum_enf_4,lenf = enf_filtro(path_enf,0,70,'2012/01/01','2012/12/31',98,db_date,'IJ','non')
ciclo_enf(lenf,'2012')
sum_enf_4,lenf = enf_filtro(path_enf,0,120,'2013/01/01','2013/12/31',98,db_date,'IJ','non')
ciclo_enf(lenf,'2013')
sum_enf_4,lenf = enf_filtro(path_enf,0,120,'2015/01/01','2015/12/31',98,db_date,'IJ','non')
ciclo_enf(lenf,'2015')
sum_enf_4,lenf = enf_filtro(path_enf,0,120,'2016/01/01','2016/12/31',98,db_date,'IJ','non')
lenf.insert(0,0)
lenf.insert(10,0)
ciclo_enf(lenf,'2016')
# Out:
# 2012-01-01 00:00:00
# 2012-01-03 00:00:00
# 2012-01-03 00:00:00
# 2012-01-03 00:00:00
# 2012-01-03 00:00:00
# 2012-01-04 00:00:00
# 2012-01-05 00:00:00
# 2012-01-06 00:00:00
# 2012-01-14 00:00:00
# 2012-01-14 00:00:00
# 2012-01-15 00:00:00
# 2012-01-16 00:00:00
# 2012-01-16 00:00:00
# 2012-01-16 00:00:00
# 2012-01-18 00:00:00
# 2012-01-18 00:00:00
# 2012-01-18 00:00:00
# 2013-10-20 00:00:00
# 2013-10-21 00:00:00
# 2013-10-22 00:00:00
# 2013-10-22 00:00:00
# 2013-10-22 00:00:00
# 2013-10-23 00:00:00
# 2013-10-24 00:00:00
# 2013-10-24 00:00:00
# 2013-10-25 00:00:00
# 2013-10-25 00:00:00
# 2013-10-25 00:00:00
# 2013-10-25 00:00:00
# 2013-10-26 00:00:00
# 2013-10-26 00:00:00
# 2013-10-26 00:00:00
# 2013-10-26 00:00:00
# 2013-10-27 00:00:00
# 2013-10-27 00:00:00
# 2013-10-27 00:00:00
# 2013-10-28 00:00:00
# 2013-10-29 00:00:00
# 2013-10-29 00:00:00
# 2013-10-29 00:00:00
# 2013-10-29 00:00:00
# 2013-10-29 00:00:00
# 2013-10-30 00:00:00
# 2013-11-01 00:00:00
# 2013-11-01 00:00:00
# 2013-11-01 00:00:00
# 2013-11-02 00:00:00
# 2013-11-02 00:00:00
# 2013-11-02 00:00:00
# 2013-11-03 00:00:00
# 2013-11-03 00:00:00
# 2013-11-03 00:00:00
# 2013-11-04 00:00:00
# 2013-11-04 00:00:00
# 2013-11-05 00:00:00
# 2013-11-06 00:00:00
# 2013-11-06 00:00:00
# 2013-11-06 00:00:00
# 2013-11-07 00:00:00
# 2013-11-07 00:00:00
# 2013-11-07 00:00:00
# 2013-11-09 00:00:00
# 2013-11-09 00:00:00
# 2013-11-10 00:00:00
# 2013-11-10 00:00:00
# 2013-11-11 00:00:00
# 2013-11-11 00:00:00
# 2013-11-12 00:00:00
# 2013-11-12 00:00:00
# 2013-11-13 00:00:00
# 2013-11-13 00:00:00
# 2013-11-13 00:00:00
# 2013-11-14 00:00:00
# 2013-11-14 00:00:00
# 2013-11-15 00:00:00
# 2013-11-16 00:00:00
# 2013-11-16 00:00:00
# 2013-11-17 00:00:00
# 2013-11-17 00:00:00
# 2013-11-17 00:00:00
# 2013-11-17 00:00:00
# 2013-11-18 00:00:00
# 2013-11-18 00:00:00
# 2013-11-18 00:00:00
# 2013-11-19 00:00:00
# 2013-11-19 00:00:00
# 2013-11-19 00:00:00
# 2013-11-20 00:00:00
# 2013-11-20 00:00:00
# 2013-11-20 00:00:00
# 2013-11-21 00:00:00
# 2013-11-22 00:00:00
# 2013-11-22 00:00:00
# 2013-11-23 00:00:00
# 2013-11-24 00:00:00
# 2013-11-24 00:00:00
# 2013-11-24 00:00:00
# 2013-11-24 00:00:00
# 2013-11-25 00:00:00
# 2013-11-25 00:00:00
# 2013-11-26 00:00:00
# 2013-11-26 00:00:00
# 2013-11-26 00:00:00
# 2013-11-26 00:00:00
# 2013-11-27 00:00:00
# 2013-11-27 00:00:00
# 2013-11-28 00:00:00
# 2013-11-28 00:00:00
# 2013-11-28 00:00:00
# 2013-11-28 00:00:00
# 2013-11-29 00:00:00
# 2013-11-29 00:00:00
# 2013-11-29 00:00:00
# 2013-11-29 00:00:00
# 2013-11-30 00:00:00
# 2013-11-30 00:00:00
# 2013-12-01 00:00:00
# 2013-12-02 00:00:00
# 2013-12-02 00:00:00
