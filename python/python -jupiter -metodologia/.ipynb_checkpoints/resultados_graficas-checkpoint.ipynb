# %%
import pandas as pd
import math as mth
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

from datetime import datetime

# %%
path_cont = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_general.csv'
path_resp = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_respiratorio.csv'
path_circ = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_circulatorio.csv'
df12 = pd.read_csv(path_cont)
df_resp = pd.read_csv(path_resp)
df_circ = pd.read_csv(path_circ)

# %%
plot_fig = sb.barplot(y='B1',x='Municipio',hue='Contaminante',data=df12)
plt.title('resultados_general')
fig = plot_fig.get_figure()
fig.savefig('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_general.jpg')

# %%
plot_fig = sb.barplot(y='B1',x='Municipio',hue='Contaminante',data=df_resp)
plt.title('resultados_respiratorio')
fig = plot_fig.get_figure()
fig.savefig('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_respiratorio.jpg')

# %%
plot_fig = sb.barplot(y='B1',x='Municipio',hue='Contaminante',data=df_circ)
plt.title('resultados_circulatorio')
fig = plot_fig.get_figure()
fig.savefig('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_circulatorio.jpg')

# %%
path_10per = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_10per.csv'
df_10per = pd.read_csv(path_10per)
plot_fig = sb.barplot(y='B1',x='Municipio',hue='Contaminante',data=df_10per)
#plot_fig = plot_fig.set(title = 'resultados_10_per')
plt.title('resultados_10_per')
fig = plot_fig.get_figure()
fig.savefig('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_10per.jpg')

# %%
path_0_4 = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_0_4.csv'
df_0_4 = pd.read_csv(path_0_4)
plot_fig = sb.barplot(y='B1',x='Municipio',hue='Contaminante',data=df_0_4)
#plot_fig = plot_fig.set(title = 'resultados_10_per')
plt.title('resultados_0_4')
fig = plot_fig.get_figure()
fig.savefig('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_0_4.jpg')

# %%
path_5_59 = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_5_59.csv'
df_5_59 = pd.read_csv(path_5_59)
plot_fig = sb.barplot(y='B1',x='Municipio',hue='Contaminante',data=df_5_59)
#plot_fig = plot_fig.set(title = 'resultados_10_per')
plt.title('resultados_5_59')
fig = plot_fig.get_figure()
fig.savefig('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_5_59.jpg')

# %%
path_60_74 = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_60_74.csv'
df_60_74 = pd.read_csv(path_60_74)
plot_fig = sb.barplot(y='B1',x='Municipio',hue='Contaminante',data=df_60_74)
#plot_fig = plot_fig.set(title = 'resultados_10_per')
plt.title('resultados_60_74')
fig = plot_fig.get_figure()
fig.savefig('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_60_74.jpg')

# %%
path_75_120 = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_75_120.csv'
df_75_120 = pd.read_csv(path_75_120)
plot_fig = sb.barplot(y='B1',x='Municipio',hue='Contaminante',data=df_75_120)
#plot_fig = plot_fig.set(title = 'resultados_10_per')
plt.title('resultados_75_120')
fig = plot_fig.get_figure()
fig.savefig('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/resultados/resultados_75_120.jpg')

# %%
df12.plot.bar(x = 'Municipio', y = 'B1')
display(df12)

# %%
def contaminante_filtro(strcont,contaminante,f_inicio,f_final,date_filepath,date_columna):
    df12 = pd.read_csv(strcont)
    
    df12= df12[['Date',contaminante]]
    f_inicio = pd.to_datetime(f_inicio)
    f_final = pd.to_datetime(f_final)
    df12['Date'] = pd.to_datetime(df12['Date'])
    df12=df12.loc[(df12['Date'] >= f_inicio)&((df12['Date'] <= f_final))]
    df12_abajo=df12.loc[(df12['Date'] < '2014/01/01')]
    df12_arriba=df12.loc[(df12['Date'] > '2014/01/01')]
    df12 = df12_abajo.append(df12_arriba, ignore_index=True)
    df12 = df12.reset_index()
    df12=df12.sort_values(by='Date',ignore_index=True)
    
    suma = 0    
    c = 0
    for i in range(df12.shape[0]):
        if df12.loc[i,contaminante] == '-' or pd.isnull(df12.loc[i,contaminante]) == True or df12.loc[i,contaminante] == '_' or df12.loc[i,contaminante] =='ND':
            continue
        else:
            #print(i,df12.loc[i,contaminante])
            suma = float(df12.loc[i,contaminante])+suma
            c+=1
            
    media = suma /c
    print(media)
            
    for i in range(df12.shape[0]):
        if df12.loc[i,contaminante] == '-' or  pd.isnull(df12.loc[i,contaminante]) == True or df12.loc[i,contaminante] == '_' or  df12.loc[i,contaminante] =='ND':
            df12.loc[i,contaminante] = media
    df12[contaminante]= df12[contaminante].astype(float)
    
    date12 = pd.read_csv(date_filepath)
    date12[date_columna] = pd.to_datetime(date12[date_columna])
    date12=date12.sort_values(by=date_columna,ignore_index=True)
            
   
    lcont12 = []
    media_mensual = []
    media_suma = 0
    
    suma = df12.loc[0,contaminante]
    h = 1
    c = 0
    div_dia = 0
    media_mes = 0

    

    for j in range(df12.shape[0]):
    
        if j == df12.shape[0]-1:
            
            if df12.loc[j,'Date'] != df12.loc[j-1,'Date']:
                lcont12.append(df12.loc[j,contaminante])
            else:
                res=suma/h
                lcont12.append(res)
            continue
        elif df12.loc[j,'Date'] != date12.loc[c,date_columna]:

            while df12.loc[j,'Date'] != date12.loc[c,date_columna]:
                #print('bucle primero',df12.loc[j,'Date'], date12.loc[c,date_columna])
                c+=1
                lcont12.append(media)
            
                
        elif df12.loc[j,'Date'] == date12.loc[c,date_columna]:

            if df12.loc[j,'Date'] == df12.loc[j+1,'Date']:
                suma = df12.loc[j+1,contaminante]+suma
                h+=1
                
            elif df12.loc[j,'Date'] != df12.loc[j+1,'Date']:
                #print('diferencia',df12.loc[j+1,'Date'])
                res=suma/h
                lcont12.append(res)
                media_suma = media_suma + res
                h=1
                suma =df12.loc[j+1,contaminante]
                c+=1
                
                if df12.loc[j,'Date'].month != df12.loc[j+1,'Date'].month:
                    div_dia = df12.loc[j,'Date'].day
                    media_mes = media_suma/div_dia
                    media_mensual.append([media_mes,df12.loc[j,'Date'].month])
                    print(df12.loc[j,'Date'])
                    media_suma = 0
        
                    
    
                while df12.loc[j+1,'Date'] != date12.loc[c,date_columna]: 
                    #print('segundo  while',df12.loc[j+1,'Date'], date12.loc[c,date_columna])
                    #print(type(df12.loc[j+1,'Date'].year))
                    c+=1
                    lcont12.append(media)
            
            
            
    print('lista de contaminantes:',len(lcont12))
    
    if 31<len(lcont12)<365:
        for i in range(365-len(lcont12)):
            lcont12.append(media)
            
    l_media = []
    for i in range(5):
        l_media.append(media)
        
            
            

    return media_mensual,l_media

# %%
suma_lista = 0
if len(lista_contaminante) < 48 :
    for i in range(len(lista_contaminante)):
        suma_lista = lista_contaminante[i][0] + suma_lista

    lista_contaminante.append([suma_lista/len(lista_contaminante),12])

# %%
path_cen ='C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/guadalajara/cendb.csv'
path_obl ='C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/guadalajara/obldb.csv'
path_pintas = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/salto/pintasdb.csv'
path_mira = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/sanpedro/miradb.csv'
path_santa = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/tlajomulco/santadb.csv'
path_tlaque =  'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/sanpedro/tlaquedb.csv'
path_dorada = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/tonala/doradadb.csv'
path_valla = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/Zapopan/vallartadb.csv'
path_agui =  'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/Zapopan/aguilasdb.csv'
path_atema = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/Zapopan/atemajacdb.csv'
dates_plot = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos enfermedades/dates_plot.csv'

# %%
lista_contaminante_valla, lista_mira= contaminante_filtro(path_valla,'O3','2012/01/01','2016/12/31',dates_plot,'date')
lista_contaminante_agui, lista_mira = contaminante_filtro(path_agui,'O3','2012/01/01','2016/12/31',dates_plot,'date')
lista_contaminante_atema, lista_mira = contaminante_filtro(path_atema,'O3','2012/01/01','2016/12/31',dates_plot,'date')
# Out:
# 0.028173001596593195
# lista de contaminantes: 1462
# 0.023597528270775284
# lista de contaminantes: 1462
# 0.024181919640276075
# lista de contaminantes: 1462

# %%
lista_contaminante, lista_mira = contaminante_filtro(path_santa,'O3','2012/01/01','2016/12/31',dates_plot,'date')
# Out:
# 0.02031849770817413
# 2013-01-12 00:00:00
# 2013-02-12 00:00:00
# 2013-03-12 00:00:00
# 2013-04-12 00:00:00
# 2013-05-31 00:00:00
# 2013-06-30 00:00:00
# 2013-07-31 00:00:00
# 2013-08-31 00:00:00
# 2013-09-30 00:00:00
# 2013-10-31 00:00:00
# 2013-11-30 00:00:00
# 2013-12-31 00:00:00
# 2015-01-31 00:00:00
# 2015-02-28 00:00:00
# 2015-03-31 00:00:00
# 2015-04-30 00:00:00
# 2015-05-31 00:00:00
# 2015-06-30 00:00:00
# 2015-07-31 00:00:00
# 2015-08-31 00:00:00
# 2015-09-30 00:00:00
# 2015-10-31 00:00:00
# 2015-11-30 00:00:00
# 2015-12-31 00:00:00
# 2016-01-31 00:00:00
# 2016-02-29 00:00:00
# 2016-03-31 00:00:00
# 2016-04-30 00:00:00
# 2016-05-31 00:00:00
# 2016-06-30 00:00:00
# 2016-07-31 00:00:00
# 2016-08-31 00:00:00
# 2016-09-30 00:00:00
# 2016-10-31 00:00:00
# 2016-11-30 00:00:00
# lista de contaminantes: 1462

# %%
lista_contaminante_mira, lista_mira = contaminante_filtro(path_mira,'O3','2012/01/01','2016/12/31',dates_plot,'date')
lista_contaminante_tlaque, lista_tlaque = contaminante_filtro(path_tlaque,'O3','2012/01/01','2016/12/31',dates_plot,'date')
# Out:
# 0.01805697362016903
# lista de contaminantes: 1462
# 0.01947674005369676
# lista de contaminantes: 1462

# %%
lista_contaminante, lista_ma = contaminante_filtro(path_pintas,'NO2','2012/01/01','2016/12/31',dates_plot,'date')
# Out:
# 0.01859679004185889
# lista de contaminantes: 1462

# %%
lista_contaminante_cen, lista_ma = contaminante_filtro(path_cen,'O3','2012/01/01','2016/12/31',dates_plot,'date')
lista_contaminante_obl,lista_ma = contaminante_filtro(path_obl,'O3','2012/01/01','2016/12/31',dates_plot,'date')
# Out:
# 0.02221038736115857
# lista de contaminantes: 1462
# 0.02424926915544614
# lista de contaminantes: 1462

# %%
len(lista_contaminante)
# Out:
# 35

# %%
len(lista_contaminante_cen)

lista_contaminante = [[lista_contaminante_valla[i][0] + lista_contaminante_agui[i][0]+lista_contaminante_atema[i][0],lista_contaminante_agui[i][1]] for i in range(len(lista_contaminante_agui))]

# %%
len(lista_contaminante)
# Out:
# 47

# %%
sum_cont = 0
lcont_media = []
for i in range(12):
    i = i*4
    if i == len(lista_contaminante)-4:
        sum_cont = lista_contaminante[i][0]+ lista_contaminante[i+1][0]+lista_contaminante[i+2][0]+lista_contaminante[i+3][0]
        lcont_media.append([sum_cont/4,lista_contaminante[i][1]])
        break
        
    
    sum_cont = lista_contaminante[i][0]+ lista_contaminante[i+1][0]+lista_contaminante[i+2][0]+lista_contaminante[i+3][0]
    lcont_media.append([sum_cont/4,lista_contaminante[i][1]])
    sum_cont = 0

# %%
lcont_media
c = 1
año = '12'
for i in range(len(lcont_media)):
    if año == '14':
        año = '15'
    lcont_media[i][1] = str(lcont_media[i][1])+'_'+año
    if c == 3:
        año = str(int(año)+1)
        c = 0 
    c+=1
lcont_media
# Out:
# [[0.0821782912203151, '1_12'],
#  [0.08454992936019141, '5_12'],
#  [0.06755570086094712, '9_12'],
#  [0.08479490771996166, '1_13'],
#  [0.08760157909303107, '5_13'],
#  [0.058701503859837884, '9_13'],
#  [0.06355213390583937, '1_15'],
#  [0.08262813577961253, '5_15'],
#  [0.0644469346536361, '9_15'],
#  [0.07812006549673481, '1_16'],
#  [0.08522388498718378, '5_16'],
#  [0.07403133503665872, '9_16']]

# %%
contaminante, fecha= zip(*lcont_media)

# %%
cont_so2, f_so2= zip(*lcont_media)

# %%
cont_no2, f_no2 = zip(*lcont_media)

# %%
plt.plot(fecha, contaminante, label = 'O3')
plt.plot(f_so2, cont_so2, label = 'SO2')
plt.plot(f_no2, cont_no2, label = 'NO2')
plt.legend()
plt.title("Zapopan_contaminantes_media")
plt.savefig('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/Zapopan/Zapopan_contaminantes_media.jpg')
#plt.legend()

# %%
len(lista_contaminante)
# Out:
# 48
