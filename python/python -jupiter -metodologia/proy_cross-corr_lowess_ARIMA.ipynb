# %%
import numpy as np

from datetime import datetime

import pandas as pd

import numpy as np
import statsmodels.api as sm
from numpy.random import default_rng
from scipy import signal

temp = 'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/temperaturas/2012.csv'
temp12 = pd.read_csv(temp)

# %%
# %store -r clenf12
clenf12

# %store -r clcont12
clcont12

lcont12=clcont12
lenf12=clenf12


# %store -r arima12

# %%
colt= temp12.columns.tolist()
colt.pop(13)
colt.pop(0)
# Out:
# 'ENTIDAD 2012'

# %%
dmes = [31,29,31,30,31,30,31,31,30,31,30,31]
ltemp = []

for i in range(len(dmes)):
    for j in range(dmes[i]):
        ltemp.append(temp12.loc[9,colt[i]])
print(ltemp)       
len(ltemp)
print(type(ltemp[5]))
# Out:
# [12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 12.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 13.1, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 16.4, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, 19.9, '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', '22.1', 23.6, 23.6, 23.6, 23.6,
# ...

# %%
ltemp = [float(ele) for ele in ltemp]
type(ltemp)
# Out:
# list

# %%
correlation = signal.correlate(ltemp, lenf12, mode="full")
lags = signal.correlation_lags(365, 365, mode="full")
lag = lags[np.argmax(correlation)]
c = np.correlate(clcont12, lenf12, "full")
#print(lag)
print(lag)
print(np.max(correlation))
#q=findlay(clcont12, lenf12)
print(np.argmax(correlation))
print(correlation)
print(np.argmax(c) - c.size/2)
#correlation
# Out:
# 56
# 25796.700000000004
# 420
# [   48.53260274   133.23260274   266.33260274   447.83260274
#    593.03260274   750.33260274   835.03260274   980.23260274
#   1064.93260274  1149.63260274  1185.93260274  1258.53260274
#   1343.23260274  1391.63260274  1391.63260274  1452.13260274
#   1500.53260274  1524.73260274  1548.93260274  1573.13260274
#   1573.13260274  1573.13260274  1609.43260274  1633.63260274
#   1633.63260274  1694.13260274  1718.33260274  1754.63260274
#   1851.43260274  1899.83260274  1984.53260274  1988.54356164
#   1995.54356164  2030.74356164  2069.94356164  2106.14356164
#   2143.34356164  2150.34356164  2162.34356164  2193.54356164
#   2224.74356164  2227.74356164  2233.74356164  2240.74356164
#   2244.74356164  2268.94356164  2273.94356164  2302.14356164
#   2304.14356164  2306.14356164  2308.14356164  2308.14356164
#   2308.14356164  2311.14356164  2313.14356164  2397.84356164
#   2511.74356164  2574.24356164  2625.64356164  2669.94356164
# ...

# %%
print(type(lcont12))
print(type(lenf12))
lcont12=np.array(lcont12)
corr12=np.correlate(arima12,lenf12)
print(corr12)
corr_res=sm.tsa.stattools.ccf(lcont12, lenf12, adjusted=False)
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# [2.00817843]

# %%
vect = []
for i in range(len(lcont12)):
    vect.append(i)
    

lowess = sm.nonparametric.lowess
res_low=lowess(lenf12, vect)
print(res_low)
# Out:
# [[  0.           5.96976826]
#  [  1.           5.95431564]
#  [  2.           5.93883104]
#  [  3.           5.92331379]
#  [  4.           5.90776305]
#  [  5.           5.8921781 ]
#  [  6.           5.87655834]
#  [  7.           5.86090314]
#  [  8.           5.84521199]
#  [  9.           5.82948449]
#  [ 10.           5.81372042]
#  [ 11.           5.79791967]
#  [ 12.           5.78208231]
#  [ 13.           5.76620852]
#  [ 14.           5.75029863]
#  [ 15.           5.7343531 ]
#  [ 16.           5.71837256]
#  [ 17.           5.70235776]
#  [ 18.           5.68630941]
#  [ 19.           5.6702281 ]
#  [ 20.           5.65411424]
#  [ 21.           5.63796812]
#  [ 22.           5.62178993]
#  [ 23.           5.60557979]
#  [ 24.           5.58933774]
#  [ 25.           5.57306374]
#  [ 26.           5.5567576 ]
#  [ 27.           5.54041909]
#  [ 28.           5.5240479 ]
#  [ 29.           5.50764379]
#  [ 30.           5.49120654]
#  [ 31.           5.4747359 ]
# ...

# %%
#lenf12
#res_low=res_low.tolist()
low12=[]
for i in range(len(res_low)):
    low12.append(res_low[i][1])

# %%
print(len(arima12))
print(len(low12))
# Out:
# 365
# 365
