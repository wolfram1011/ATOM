# %%
import pandas as pd
df12 = pd.read_csv('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/cen.csv')

df12= df12[['Date','1:O3']]

from datetime import datetime

media = 20
df12['Date'] = pd.to_datetime(df12['Date'])


for i in range(df12.shape[0]):
    if df12.loc[i,'1:O3'] == '-':
        df12.loc[i,'1:O3'] = media
        

df12['1:O3'] = df12['1:O3'].astype(float)
lcont12 = []

suma = 0
h = 1
for j in range(df12.shape[0]):
    if df12.loc[j,'Date'] == df12.shape[0]-2:
         continue
    if df12.loc[j,'Date'] == df12.loc[j+1,'Date']:
        suma = df12.loc[j,'1:O3'] + df12.loc[j+1,'1:O3']
        h+=1
    else:
        lcont12.append(suma/h)
        h=1
        suma =0
  

#df12=df12.sort_values(by='INGRE',ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     350                 try:
# --> 351                     return self._range.index(new_key)
#     352                 except ValueError as err:
#
# ValueError: 8808 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-1e75ce95982c> in <module>
#      23     if df12.loc[j,'Date'] == df12.shape[0]-2:
#      24          continue
# ---> 25     if df12.loc[j,'Date'] == df12.loc[j+1,'Date']:
#      26         suma = df12.loc[j,'1:O3'] + df12.loc[j+1,'1:O3']
#      27         h+=1
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py in __getitem__(self, key)
# ...

# %%
#df12=df12.reset_index()
#display(df12)
#type(df12.loc[0,'Date'])
print(df12.shape[0])

display(df12)
# Out:
# 8808
#            Date   1:O3
# 0    2011-12-31  0.002
# 1    2011-12-31  0.003
# 2    2011-12-31  0.001
# 3    2011-12-31  0.001
# 4    2011-12-31  0.001
# ...         ...    ...
# 8803 2012-12-31  0.003
# 8804 2012-12-31  0.003
# 8805 2012-12-31  0.001
# 8806 2012-12-31  0.001
# 8807 2013-01-01  0.003
#
# [8808 rows x 2 columns]

# %%
import pandas as pd

import numpy as np

from datetime import datetime

una='C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/cen.csv'
'C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos contaminantes/obl.csv'

def limcont(strcont):
    df12 = pd.read_csv(strcont)
    ef12 = df12

    lista = []
    for row in range(ef12.shape[0]):
        lista.append(ef12.loc[row,'1:O3'])
    suma=float(0)
    mo3 = []
    for l in lista:
        if l == '-':
            #series.append(np.nan)
            continue
        else:
            mejor=float(l)
            suma = mejor +suma
            mo3.append(mejor)
    media = suma/len(mo3)
    df12= df12[['Date','1:O3']]
    df12['Date'] = pd.to_datetime(df12['Date'])
    
    for i in range(df12.shape[0]):
        if df12.loc[i,'1:O3'] == '-':
            df12.loc[i,'1:O3'] = media
    df12['1:O3'] = df12['1:O3'].astype(float)
    lcont12 = []
    suma = 0
    h = 1
    df12=df12.reset_index()
    
    for j in range(df12.shape[0]):
        
        

    
    
    return df12

df12 = limcont(una)
# Out:
# <ipython-input-47-262a714266d8>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df12['Date'] = pd.to_datetime(df12['Date'])
# C:\Users\ASTRONAUTA\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# <ipython-input-47-262a714266d8>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df12
# Out:
#       index       Date   1:O3
# 0        23 2012-01-01  0.002
# 1        24 2012-01-01  0.004
# 2        25 2012-01-01  0.005
# 3        26 2012-01-01  0.003
# 4        27 2012-01-01  0.006
# ...     ...        ...    ...
# 8778   8801 2012-12-31  0.004
# 8779   8802 2012-12-31  0.004
# 8780   8803 2012-12-31  0.003
# 8781   8804 2012-12-31  0.003
# 8782   8805 2012-12-31  0.001
#
# [8783 rows x 3 columns]

# %%
import pandas as pd
date12 = pd.read_csv('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos enfermedades/dates.csv')
date12['date'] = pd.to_datetime(date12['date'])
date12=date12.sort_values(by='date',ignore_index=True)
date12=date12['date'].tolist()
print(date12)
# Out:
# [Timestamp('2012-01-01 00:00:00'), Timestamp('2012-01-02 00:00:00'), Timestamp('2012-01-03 00:00:00'), Timestamp('2012-01-04 00:00:00'), Timestamp('2012-01-05 00:00:00'), Timestamp('2012-01-06 00:00:00'), Timestamp('2012-01-07 00:00:00'), Timestamp('2012-01-08 00:00:00'), Timestamp('2012-01-09 00:00:00'), Timestamp('2012-01-10 00:00:00'), Timestamp('2012-01-11 00:00:00'), Timestamp('2012-01-12 00:00:00'), Timestamp('2012-01-13 00:00:00'), Timestamp('2012-01-14 00:00:00'), Timestamp('2012-01-15 00:00:00'), Timestamp('2012-01-16 00:00:00'), Timestamp('2012-01-17 00:00:00'), Timestamp('2012-01-18 00:00:00'), Timestamp('2012-01-19 00:00:00'), Timestamp('2012-01-20 00:00:00'), Timestamp('2012-01-21 00:00:00'), Timestamp('2012-01-22 00:00:00'), Timestamp('2012-01-23 00:00:00'), Timestamp('2012-01-24 00:00:00'), Timestamp('2012-01-25 00:00:00'), Timestamp('2012-01-26 00:00:00'), Timestamp('2012-01-27 00:00:00'), Timestamp('2012-01-28 00:00:00'), Timestamp('2012-01-29 00:00:00'), Timestamp('
# ...

# %%
import pandas as pd
enf12 = pd.read_csv('C:/Users/ASTRONAUTA/Documents/UNADM PROYECTO TERMINAL/datos enfermedades/ssa_egresos_2012/EGRESO_2012.csv')
display(enf12)
# Out:
# C:\Users\ASTRONAUTA\AppData\Roaming\Python\Python39\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (2,5,13,15,30,34,35,36,39,40,41,44,45,47,48,81,82) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#               ID        CLUES   FOLIO      EGRESO       INGRE DIAS_ESTA  \
# 0          83806  BCSSA018046  100884  31/01/2012  29/01/2012         2
# 1          83858  BCSSA018046  100885  31/01/2012  23/01/2012         8
# 2          83870  BCSSA018046  100886  30/01/2012  29/01/2012         1
# 3          83888  BCSSA018046  100887  29/01/2012  28/01/2012         1
# 4          83954  BCSSA018046  100888  27/01/2012  26/01/2012         1
# ...          ...          ...     ...         ...         ...       ...
# 1048570  1037984  JCSSA002171   24538  20/08/2012  20/08/2012         0
# 1048571  1038002  JCSSA002171   24539  20/08/2012  20/08/2012         0
# ...
